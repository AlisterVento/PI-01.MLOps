# %% [markdown]
# # **ETL del archivo User_items_Analisis**

# %% [markdown]
# ## **1.Cargando Las Librerías Necesarias**

# %%
import pandas as pd #Cargaremos pandas para manejar los datos",
import numpy as np #Cargaremos numpy para manejar los datos,
import json as json  #Cargaremos json para manejar los datos",
import gzip #Cargaremos gzip para manejar los datos,
import ast
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
url03=r'/content/drive/MyDrive/2023/Henry/MLOps Henry/Data/users_items.json.gz'

# %% [markdown]
# ## **2.Fase ETL**

# %% [markdown]
# ### 2.1.Carga de Datos

# %%
#Procederemos a leer el documento con gzip

filas=[]
with gzip.open(url03) as file:
    for line in file.readlines():
        line = line.decode('utf-8')
        filas.append(ast.literal_eval(line))

df_user_items = pd.DataFrame(filas)
df_user_items.head()
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1            js41637          888  76561198035864385
# 2          evcentric          137  76561198007712555
# 3         Riot-Punch          328  76561197963445855
# 4              doctr          541  76561198002099482
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1               http://steamcommunity.com/id/js41637
# 2             http://steamcommunity.com/id/evcentric
# 3            http://steamcommunity.com/id/Riot-Punch
# 4                 http://steamcommunity.com/id/doctr
#
#                                                items
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 2  [{'item_id': '1200', 'item_name': 'Red Orchest...
# 3  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 4  [{'item_id': '300', 'item_name': 'Day of Defea...

# %% [markdown]
# ### 2.2.Análisis De Descriptivo De Los Datos

# %% [markdown]
# #### 2.2.1.Funciones Para El Analisis Descriptivo De Los Datos

# %%
def check_df(dataset, head = 5):
    """
    Funcion creada para tener una vista general de la base de datos
    """
    print('*'*30 + 'Forma de la base de datos' + '*'*30, end = '\n'*2)
    print(dataset.shape, end = '\n'*2)#Tamaño de la base de datos

    print('*'*30 + 'Informacion general de la base de datos' + '*'*30, end = '\n'*2)
    print(dataset.info(), end = '\n'*2)# Informacion general

    print('*'*30 + 'NaN cantidad de nulos' + '*'*30, end = '\n'*2)
    print(dataset.isnull().sum(), end = '\n'*2)#Cuenta la cantidad de NaN por columna

# %% [markdown]
# #### 2.2.2.Descripcion De Los Datos

# %%
check_df(df_user_items)
# Out:
# ******************************Forma de la base de datos******************************
#
# (88310, 5)
#
# ******************************Informacion general de la base de datos******************************
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88310 entries, 0 to 88309
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      88310 non-null  object
#  1   items_count  88310 non-null  int64
#  2   steam_id     88310 non-null  object
#  3   user_url     88310 non-null  object
#  4   items        88310 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.4+ MB
# None
#
# ******************************NaN cantidad de nulos******************************
#
# user_id        0
# items_count    0
# steam_id       0
# user_url       0
# items          0
# dtype: int64

# %% [markdown]
# ### 2.3.Transformacion de Datos

# %%
df_user_items  = df_user_items.explode('items')

# %%
df_user_items
# Out:
#                  user_id  items_count           steam_id  \
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# ...                  ...          ...                ...
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
# 88309  edward_tremethick            0  76561198331598578
#
#                                                 user_url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 0      http://steamcommunity.com/profiles/76561197970...
# 0      http://steamcommunity.com/profiles/76561197970...
# ...

# %%
df_user_items.isnull().sum()
# Out:
# user_id            0
# items_count        0
# steam_id           0
# user_url           0
# items          16806
# dtype: int64

# %%
df_user_items.dropna(subset=['items'],inplace=True)

# %%
df_user_items
# Out:
#                  user_id  items_count           steam_id  \
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# ...                  ...          ...                ...
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
#
#                                                 user_url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 0      http://steamcommunity.com/profiles/76561197970...
# 0      http://steamcommunity.com/profiles/76561197970...
# ...

# %%
for elemento,diccionario in df_user_items['items'].head().items():
    df=pd.DataFrame(columns =  diccionario.keys())
df
# Out:
# Empty DataFrame
# Columns: [item_id, item_name, playtime_forever, playtime_2weeks]
# Index: []

# %%
new_rows = []

# Iterate over the dictionaries in the 'reviews' column
for elemento, diccionario in df_user_items['items'].items():
    new_row = pd.DataFrame(diccionario, index=[elemento])  # Create a new row DataFrame
    new_rows.append(new_row)  # Append the new row to the list

# Concatenate the list of new rows with the original DataFrame
result_df = pd.concat([df, *new_rows])

# %%
# Reset index
df_user_items = df_user_items.join(result_df)

# %% [markdown]
# Procederemos a eliminar las columnas que ya no son necesarias

# %%
df_user_items.drop_duplicates(subset=['user_id','item_name'],inplace=True)

# %% [markdown]
# El notebook fue trabajado en un jupyter notebook de manera offline sin embargo el resultado no se pudo volver a generar y visualizar  debido a la alta demanda computacional y memoria, sin embargo el resultado se pudo guardar en un archivo **parquet** el cual lo usaremos cargaremos desde google drive

# %% [markdown]
# ### 3.Exportacion

# %%
url05=r'/content/drive/MyDrive/2023/Henry/MLOps Henry/Data_Clean/clean_user_items.parquet.gzip'

# %%
result_df =  pd.read_parquet(url05)

# %%
result_df
# Out:
#                  user_id  items_count           steam_id  \
# index
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# ...                  ...          ...                ...
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
#
#                                                 user_url item_id  \
# index
# 0      http://steamcommunity.com/profiles/76561197970...      10
# 0      http://steamcommunity.com/profiles/76561197970...      20
# 0      http://steamcommunity.com/profiles/76561197970...      30
# ...

# %% [markdown]
# Cambiamos el nombre a las columnas extraidas

# %%
result_df = result_df.rename(columns={'items.item_id':'item_id',
                                   'items.item_name':'item_name',
                                      'items.playtime_2weeks':'playtime_2weeks',
                                      'items.playtime_forever':'playtime_forever'})

# %% [markdown]
# Sobre escribimos el archivo

# %%
result_df.to_parquet(url05, compression='gzip',index=False)
